# %%
import pandas as pd
import numpy as np

# %%
# dataset_path = 'https://raw.githubusercontent.com/ProgressBG-Python-Course/JupyterNotebooksExamples/master/datasets/various/drinks.csv'
dataset_path='../datasets/drinks.csv'
df = pd.read_csv(dataset_path)
df.head(5)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %% [markdown]
# ## Select rows/columns

# %%
# select only 2 columns
df.loc[:,['wine_servings','continent']]

# %%
# swap column names:
# df[['country', 'beer_servings']] = df[['beer_servings','country']]
# df.head(5)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
#select rows:  [5 - 10], and columns: wine_servings : continent
df.loc[5:10,'wine_servings':'continent']

# %%
#select country and continent from odd row numbers
df.loc[1::2, ['country','continent']]

# %%
# select rows for which wine servings > 300
df[df.wine_servings > 300]
# Out:
#       country  beer_servings  spirit_servings  wine_servings  \
# 3     Andorra            245              138            312
# 61     France            127              151            370
# 136  Portugal            194               67            339
#
#      total_litres_of_pure_alcohol continent
# 3                            12.4        EU
# 61                           11.8        EU
# 136                          11.0        EU

# %%
# select country names for which wine servings > 300
# df[df.wine_servings > 300]['country'] # bad
df.loc[df.wine_servings > 300, 'country'] # good
# Out:
# 3       Andorra
# 61       France
# 136    Portugal
# Name: country, dtype: object

# %%
# set country values as index
df.set_index('country', inplace=True)
df.head(5)
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0        AS
# Albania                               4.9        EU
# Algeria                               0.7        AF
# Andorra                              12.4        EU
# Angola                                5.9        AF

# %%
# TASK: select rows for index values in given interval
df.loc['Bahamas':'Bulgaria']
# Out:
#                     beer_servings  spirit_servings  wine_servings  \
# country
# Bahamas                       122              176             51
# Bahrain                        42               63              7
# Bangladesh                      0                0              0
# Barbados                      143              173             36
# Belarus                       142              373             42
# Belgium                       295               84            212
# Belize                        263              114              8
# Benin                          34                4             13
# Bhutan                         23                0              0
# Bolivia                       167               41              8
# Bosnia-Herzegovina             76              173              8
# Botswana                      173               35             35
# Brazil                        245              145             16
# Brunei                         31                2              1
# Bulgaria                      231              252             94
#
#                     total_litres_of_pure_alcohol continent
# country
# Bahamas                                      6.3       NaN
# Bahrain                                      2.0        AS
# Bangladesh                                   0.0        AS
# Barbados                                     6.3       NaN
# Belarus                                     14.4        EU
# Belgium                                     10.5        EU
# Belize                                       6.8       NaN
# Benin                                        1.1        AF
# Bhutan                                       0.4        AS
# Bolivia                                      3.8        SA
# Bosnia-Herzegovina                           4.6        EU
# Botswana                                     5.4        AF
# Brazil                                       7.2        SA
# Brunei                                       0.6        AS
# Bulgaria                                    10.3        EU

# %%
# reset index
df.reset_index(drop=False,inplace=True)
df.head(5)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
#select all rows and all columns, without 'country', 'continent'

# df.loc[:, 'beer_servings':'total_litres_of_pure_alcohol']
df.iloc[:, 1:-1]

# %%
# select last 3 columns:
df.iloc[:, 1:-1]

# %% [markdown]
# ## insert/drop columns

# %%
# Insert column  named 'random' with random integers in [1..10], in the beginnig (i.e. at index 0)

rand_ints = np.random.randint(1, high=11, size=df.shape[0])

df.insert(0, 'random', rand_ints)
df.head()
# np.random.randint?
# Out:
#    random      country  beer_servings  spirit_servings  wine_servings  \
# 0       7  Afghanistan              0                0              0
# 1      10      Albania             89              132             54
# 2       5      Algeria             25                0             14
# 3       5      Andorra            245              138            312
# 4       1       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
# drop column 'random':
df.drop(columns='random', inplace=True)

# %%
df.head(3)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF

# %% [markdown]
# ## Useful properties and methods

# %%
df.shape
# Out:
# (193, 6)

# %%
df.index

# %%
df.columns

# %%
df.info()

# %%
df.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
# select country names, which 'total_litres_of_pure_alcohol' == max
mask = df.total_litres_of_pure_alcohol == df.total_litres_of_pure_alcohol.max()

df.loc[mask, ['country','total_litres_of_pure_alcohol']]
# df.loc[mask]
# Out:
#     country  total_litres_of_pure_alcohol
# 15  Belarus                          14.4

# %%
# select country names, which 'beer_servings' > 75%
beer_df = df.loc[ df.beer_servings >df.beer_servings.quantile(0.75),:'beer_servings']
beer_df.head(3)
# Out:
#      country  beer_servings
# 3    Andorra            245
# 4     Angola            217
# 6  Argentina            193

# %%
beer_df.sort_values(by='beer_servings').head(10)
# Out:
#                 country  beer_servings
# 44               Cyprus            192
# 6             Argentina            193
# 51   Dominican Republic            193
# 136            Portugal            194
# 143   St. Kitts & Nevis            194
# 155            Slovakia            196
# 174   Trinidad & Tobago            197
# 68              Grenada            199
# 121         New Zealand            203
# 180             Ukraine            206

# %%
# max by column values
# df.max(axis=0)

# max by rows values
df.max(axis=0)
# Out:
# /tmp/ipykernel_42594/3608777183.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max(axis=0)
# country                         Zimbabwe
# beer_servings                        376
# spirit_servings                      438
# wine_servings                        370
# total_litres_of_pure_alcohol        14.4
# dtype: object

# %%
df.head(5)

# %%
# TASK: find the max value for Bulgaria
df.loc[df.country=='Bulgaria'].max(axis=1)

# %%
df.head(3)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF

# %%
df.groupby('continent').wine_servings.count()
# Out:
# continent
# AF    53
# AS    44
# EU    45
# OC    16
# SA    12
# Name: wine_servings, dtype: int64

# %%
null_mask = df.continent.isnull().values
df.loc[null_mask]

# %%
df.sort_values(by='wine_servings', axis=0)

# %% [markdown]
# ##
